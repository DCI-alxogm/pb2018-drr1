# %%
##se importal librerias necesarias
import numpy as np
import matplotlib.pyplot as plt
import scipy.constants as cte

# %matplotlib inline

# %%
## se definen las constantes
k=cte. Boltzmann
h=cte. Planck
c=cte. c

# %%
info=np.loadtxt('IRCF.txt') ##para leer del archivo los datos por filas
i1=info[:,0]
i2=info[:,1]
i3=info[:,3]
i3*=1e-3

# %%
plt.plot(i1,i2,"-o") ##para graficar
plt.title("Radiación de fondo de microondas")
# Out:
# Text(0.5,1,'Radiación de fondo de microondas')

# %%
def I(v,T): ##se define la funcion
    for i in range (100):
        T[i]=np.linspace(1,300,100)
        v=i1[i]*3*10**10
        z[i]*=z[i]*10**-26
        z[i]=(((h*(pow(v,3)))/(pow(c,2)))*(1/((np.exp((h*v)/(k*T[i])))-1)))*(pow(10,26))
        return z[i]

# %%
plt.plot(z,i2,color="red")
